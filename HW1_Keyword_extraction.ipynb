# %%
                                                import json, os
import pandas as pd
from nltk.corpus import stopwords
import numpy as np
from pymorphy2 import MorphAnalyzer
from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer
morph = MorphAnalyzer()
stops = set(stopwords.words('russian'))

# %%
#import nltk
#nltk.download()

# %%
pd.set_option('display.max_colwidth', 1000)

# %% [markdown]
# ## Данные

# %%
# скачаем данные в папке data и распакуем их
PATH_TO_DATA = './data' #ng_0.jsonlines
PATH_TO_DATA = './ng'

# %%
files = [os.path.join(PATH_TO_DATA, file) for file in os.listdir(PATH_TO_DATA)]

# %% [markdown]
# Объединим файлы в один датасет.

# %%
data = pd.concat([pd.read_json(file, lines=True) for file in files][:1], axis=0, ignore_index=True)

# %%
data.shape
# Out:
# (988, 5)

# %%
#data.head(6)

# %%
# за что отвечает [1:2], и почему мы берём меньше?
data1 = pd.concat([pd.read_json(file, lines=True) for file in files][1:2], axis=0, ignore_index=True)

# %%
def evaluate(true_kws, predicted_kws):
  #  assert len(true_kws) == len(predicted_kws)
    
    precisions = []
    recalls = []
    f1s = []
    jaccards = []
    
    for i in range(len(true_kws)):
        true_kw = set(true_kws[i])
        predicted_kw = set(predicted_kws[i])
        
        tp = len(true_kw & predicted_kw)
        union = len(true_kw | predicted_kw)
        fp = len(predicted_kw - true_kw)
        fn = len(true_kw - predicted_kw)
        
        if (tp+fp) == 0:
            prec = 0
        else:
            prec = tp / (tp + fp)
        
        if (tp+fn) == 0:
            rec = 0
        else:
            rec = tp / (tp + fn)
        if (prec+rec) == 0:
            f1 = 0
        else:
            f1 = (2*(prec*rec))/(prec+rec)
            
        jac = tp / union
        
        precisions.append(prec)
        recalls.append(rec)
        f1s.append(f1)
        jaccards.append(jac)
    print('Precision - ', round(np.mean(precisions), 2)) # 2 means ?
    print('Recall - ', round(np.mean(recalls), 2))
    print('F1 - ', round(np.mean(f1s), 2))
    print('Jaccard - ', round(np.mean(jaccards), 2))

# %% [markdown]
# Проверим, что всё работает как надо.

# %%
evaluate(data['keywords'], data['keywords'])
# Out:
# Precision -  1.0
# Recall -  1.0
# F1 -  1.0
# Jaccard -  1.0

# %% [markdown]
# ## Токенизация, удаление стоп-слов и нормализация.

# %%
from string import punctuation
from nltk.corpus import stopwords
punct = punctuation+'0123456789«»—…“”*№–'
stops = set(stopwords.words('russian'))

def normalize(text):
    
    words = [word.strip(punct) for word in text.lower().split()]
    words = [morph.parse(word)[0].normal_form for word in words if word and word not in stops]

    return words

# %%
import time
start = time.time()
data['content_norm'] = data['content'].apply(normalize)
end = time.time()
print(end - start)
# Out:
# 179.81707334518433

# %%
def normalize(text):
    
    words = [word.strip(punct) for word in text.lower().split()]
    words = [morph.parse(word)[0] for word in words if word and word not in stops]
    words = [word.normal_form for word in words if word.tag.POS == 'NOUN']

    return words

# %%
data['content_norm'] = data['content'].apply(normalize)

# %%
evaluate(data['keywords'], data['content_norm'].apply(lambda x: [x[0] for x in Counter(x).most_common(7)]))
# Out:
# Precision -  0.13
# Recall -  0.19
# F1 -  0.15
# Jaccard -  0.09

# %% [markdown]
# # Способ №1.
#
# Сделать min_df = 2 (means "ignore terms that appear in less than 2 documents”).
# [Это ничего не изменит, но можно ещё сделать max_df = 0.80 (means "ignore terms that appear in more than 80% documents”)]
# Результат: F1 = 0.17

# %%
# можно заодно сделать нграммы
tfidf = TfidfVectorizer(ngram_range=(1,3), max_df = 0.80, min_df=2)

# %%
tfidf.fit(data['content_norm_str'])
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=0.8, max_features=None, min_df=2,
#         ngram_range=(1, 3), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words=None, strip_accents=None, sublinear_tf=False,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
id2word = {i:word for i,word in enumerate(tfidf.get_feature_names())}

# %% [markdown]
# Преобразуем наши тексты в векторы, где на позиции i стоит tfidf коэффициент слова i из словаря.

# %%
texts_vectors = tfidf.transform(data['content_norm_str'])

# %% [markdown]
# Отсортируем векторы текстов по этим коэффициентам и возьмем топ-10.

# %%
# сортировка по убыванию, поэтому нужно развернуть список
keywords = [[id2word[w] for w in top] for top in texts_vectors.toarray().argsort()[:,:-11:-1]]

# %%
keywords[:2]
# Out:
# [['ольга васильев',
#   'стандарт',
#   'васильев',
#   'ольга',
#   'источник',
#   'предмет',
#   'письмо',
#   'произведение',
#   'редакция',
#   'содержание'],
#  ['красота',
#   'отчаяние',
#   'порыв',
#   'кошка',
#   'глаз',
#   'руина',
#   'красота глаз',
#   'предмет',
#   'банкнот',
#   'занавеска']]

# %%
evaluate(data['keywords'], keywords)
# Out:
# Precision -  0.13
# Recall -  0.25
# F1 -  0.17
# Jaccard -  0.1

# %% [markdown]
# F-мера стала лучше на 0.01, но всё ещё попадается мусор ("при", "ольга", "борода" - такие себе ключевые слова).

# %% [markdown]
# # Способ № 2.
#
#
# Если брать не 10 слов из обработанных, а 7, то получится ещё чуть лучше:
# F1 -  0.18

# %%
# исходная версия tfidf, не как в способе № 1
tfidf = TfidfVectorizer(ngram_range=(1,2), min_df=5)

# %%
# сортировка по убыванию, поэтому нужно развернуть список
keywords = [[id2word[w] for w in top] for top in texts_vectors.toarray().argsort()[:,:-7:-1]]

# %%
tfidf.fit(data['content_norm_str'])
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=5,
#         ngram_range=(1, 2), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words=None, strip_accents=None, sublinear_tf=False,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
id2word = {i:word for i,word in enumerate(tfidf.get_feature_names())}

# %%
texts_vectors = tfidf.transform(data['content_norm_str'])

# %%
# сортировка по убыванию, поэтому нужно развернуть список
keywords = [[id2word[w] for w in top] for top in texts_vectors.toarray().argsort()[:,:-6:-1]]

# %%
keywords[:2]
# Out:
# [['ольга васильев', 'стандарт', 'васильев', 'ольга', 'источник'],
#  ['красота', 'отчаяние', 'порыв', 'кошка', 'глаз']]

# %%
evaluate(data['keywords'], keywords)
# Out:
# Precision -  0.19
# Recall -  0.18
# F1 -  0.17
# Jaccard -  0.11

# %%
keywords
# Out:
# ['элитарным развлечением',
#  'экспрессивным слогом',
#  'шарль дидло',
#  'чудовищными ошибками',
#  'художественный феномен',
#  'феерия ?..',
#  'театральных афишах',
#  'театр вслед',
#  'сумел закрепиться',
#  'стоила одна',
#  'современным балетам',
#  'собирал знания',
#  'словам яковлевой',
#  'склоне дней',
#  'сергей худеков',
#  'самых истоков',
#  'русскую почву',
#  'русские танцовщицы',
#  'разнообразные вопросы',
#  'равно просачивались',
#  'прозвищу веретено',
#  'приклеивай бренд',
#  'приказ короля',
#  'правильно подавать',
#  'пору конкурировали',
#  'попытка увидеть',
#  'петербургской газеты',
#  'отмечает автор',
#  'отзыву современника',
#  'особым удовольствием',
#  'обманывали ожиданий',
#  'неоткрытой звезды',
#  'невиданного совершенства',
#  'начинает исследовательница',
#  'намоченным свернутым',
#  'надолго воцарились',
#  'молниеносные прыжки',
#  'модные спектакли',
#  'многом умалчивают',
#  'многие танцовщицы',
#  'мире »).',
#  'министру двора',
#  'мариинском театре',
#  'маневров гвардии',
#  'ловким карьеристом',
#  'красном селе',
#  'константин скальковский',
#  'каллиграфическими прыжками',
#  'искусство сохранили',
#  'известнейший специалист',
#  'забывал учиться',
#  'жюль перро',
#  'жгут полотенцем',
#  'делал карьеру',
#  'дворянами ринулись',
#  'городских площадей',
#  'главным балетмейстером',
#  'высоким ценам',
#  'выдающегося хореографа',
#  'вирджиния цукки',
#  'видели зрители',
#  'век балерин',
#  'биография хореографа',
#  'батиста ланде',
#  'балетоманы победнее',
#  'балетные школы',
#  'балерин готовили',
#  'афиши встречались',
#  'артур сен',
#  'автор книги',
#  '52 годам',
#  'театр петипа',
#  'русский балет',
#  'мариус петипа',
#  'зеркале балета',
#  'балета »,',
#  'балет ».',
#  'вышла книга',
#  'возникла первая',
#  'петипа',
#  'балета',
#  'балет',
#  'первая',
#  'книга',
#  'эпохе',
#  'эмоциональной',
#  'эксплуататорах',
#  'читается',
#  'числе',
#  'хореографом',
#  'французская',
#  'ушел',
#  'училище',
#  'танцовщика',
#  'таки',
#  'сцену',
#  'стихотворение',
#  'спектакль',
#  'спектаклей',
#  'состояла',
#  'создавший',
#  'советское',
#  'смотрели',
#  'следует',
#  'сезон',
#  'санкт',
#  'салтыков',
#  'садоводству',
#  'россии',
#  'роман',
#  'редактор',
#  'прошлое',
#  'профессиональным',
#  'примеру',
#  'примадонн',
#  'преподавателем',
#  'предпочитал',
#  'планомерно',
#  'пишет',
#  'писательница',
#  'писателей',
#  'писали',
#  'петербурге',
#  'петербург',
#  'перо',
#  'педагога',
#  'отвечает',
#  'осторожным',
#  'основном',
#  'нувориши',
#  'например',
#  'напоминал',
#  'написанные',
#  'муж',
#  'минкуса',
#  'министры',
#  'метивший',
#  'места',
#  'мемуары',
#  'мастера',
#  'малообразованными',
#  'летом',
#  'леон',
#  'корсета',
#  'конец',
#  'й',
#  'итальянская',
#  'империи',
#  'издатель',
#  'зрителями',
#  'знал',
#  'занимались',
#  'зале',
#  'зал',
#  'долгую',
#  'годы',
#  'вторая',
#  'встретить',
#  'войне',
#  'взялся',
#  'вело',
#  'века',
#  'быстро',
#  'большевикам',
#  'бельэтаж',
#  'балетмейстеров',
#  'артистки',
#  'адаптируя',
#  '40',
#  '28',
#  '1917',
#  '1890',
#  '1737',
#  '150']

# %% [markdown]
# # Способ № 3
#
# Если соединить способы 1 и 2, F-мера станет 0.18.

# %%
tfidf = TfidfVectorizer(ngram_range=(1,3), max_df = 0.80, min_df=2)

tfidf.fit(data['content_norm_str'])

id2word = {i:word for i,word in enumerate(tfidf.get_feature_names())}

texts_vectors = tfidf.transform(data['content_norm_str'])

keywords = [[id2word[w] for w in top] for top in texts_vectors.toarray().argsort()[:,:-6:-1]] 

keywords[:2]

evaluate(data['keywords'], keywords)
# Out:
# Precision -  0.19
# Recall -  0.18
# F1 -  0.18
# Jaccard -  0.11

# %% [markdown]
# # Способ № 4
#
# Попробовать новые стоп-слова на просто частотной выборке. F1 -  0.17

# %%
from string import punctuation
from nltk.corpus import stopwords
from stop_words import get_stop_words

punct = punctuation+'«»—…“”*№–' # '0123456789«»—…“”*№–' изначально было без цифр
stop_words = set(get_stop_words('ru'))
#print(stop_words)

def normalize(text):
    
    words = [word.strip(punct) for word in text.lower().split()]
    words = [morph.parse(word)[0] for word in words if word and word not in stop_words]
    words = [word.normal_form for word in words if word.tag.POS == 'NOUN']

    return words

# %%
data['content_norm'] = data['content'].apply(normalize)

# %%
# топ 10 частотных слов статьи
evaluate(data['keywords'], data['content_norm'].apply(lambda x: [x[0] for x in Counter(x).most_common(10)]))
# Out:
# Precision -  0.14
# Recall -  0.26
# F1 -  0.17
# Jaccard -  0.1

# %% [markdown]
# А если использовать с новыми стоп-словами tf-idf, ничего не изменится.

# %%
tfidf = TfidfVectorizer(ngram_range=(1,3), max_df = 0.80, min_df=2)

tfidf.fit(data['content_norm_str'])

id2word = {i:word for i,word in enumerate(tfidf.get_feature_names())}

texts_vectors = tfidf.transform(data['content_norm_str'])

keywords = [[id2word[w] for w in top] for top in texts_vectors.toarray().argsort()[:,:-6:-1]] 

keywords[:2]

evaluate(data['keywords'], keywords)

# %% [markdown]
# Возьмем этот результат за baseline.

# %% [markdown]
# Precision -  0.13
# Recall -  0.24
# F1 -  0.16
# Jaccard -  0.09

# %% [markdown]
# # Способ №5.
#
# Попробуем TermExtractor, F-мера станет 0.17
#
# Источник: https://github.com/igor-shevchenko/rutermextract
# nested true попробовать

# %%
from rutermextract import TermExtractor

term_extractor = TermExtractor()

vse_1 = []
for i in data['content']:
    t_extr = []
    for term in term_extractor(''.join(i), limit = 5):
        t_extr.append(term.normalized)
    vse_1.append(t_extr)

# %%
print(len(vse_1))
# Out:
# 988

# %%
evaluate(data['keywords'], vse_1)
# Out:
# Precision -  0.18
# Recall -  0.17
# F1 -  0.17
# Jaccard -  0.1

# %% [markdown]
# # Способ № 6
#
# Попробуем Rake. Жалкая F-мера: 0.03.
#
# Из NLTK: https://github.com/csurfer/rake-nltk

# %%
from rake_nltk import Rake

# %%
from stop_words import get_stop_words

punctuations = punctuation+'0123456789«»—…“.,”*№–' # '0123456789«»—…“”*№–' изначально было без цифр
stop_words = set(get_stop_words('ru'))

# %%
r = Rake(language="ru", stopwords=list(stop_words), punctuations=punctuations, min_length=1, max_length=1)

# Extraction given the text.
rake_keywords = []
for text in data['content']:
    r.extract_keywords_from_text(text)
    keywords = r.get_ranked_phrases()
    #c=r.get_ranked_phrases_with_scores()
    rake_keywords.append(keywords[:20])
print(rake_keywords)
# Out:
# [['явлениях', 'явления', 'явлений', 'читают', 'читали', 'читала', 'числе', 'цифра', 'фгосам', 'фгос', 'ученики', 'уроке', 'увязываю', 'темы', 'таблицу', 'схему', 'страничке', 'стихотворений', 'стихи', 'стать'], ['ясно', 'шах', 'шалея', 'чьих', 'чужая', 'чеширски', 'честью', 'храмина', 'хорошим', 'хорошие', 'хорошее', 'ходит', 'хлоп', 'уясните', 'ушла', 'утверждении', 'успокоительное', 'условия', 'умиротворение', 'укорот'], ['якутского', 'якутии', 'юзефович', 'экзотический', 'штаны', 'шинели', 'холода', 'х', 'фронты', 'фаталист', 'успех', 'унылой', 'тунгусов', 'точь', 'томске', 'той', 'темой', 'тема', 'сюжету', 'сысы'], ['является', 'эффективно', 'эндом', 'энд', 'штабе', 'чудо', 'чувствовал', 'чемпионате', 'целом', 'хромают', 'хочу', 'формулы', 'формуле', 'формула', 'финише', 'финиша', 'учитывать', 'уступали', 'умеют', 'уильямсы'], ['яростью', 'юпитеры', 'юбилейное', 'эрлихом', 'эрлих', 'эпизод', 'шли', 'чувствую', 'чувствовал', 'чувствительные', 'чистейшей', 'число', 'черный', 'человеком', 'цветы', 'хочет', 'хотелось', 'хлеб', 'ушло', 'ушел'], ['учиться', 'тиаго', 'творческий', 'талантливый', 'считаю', 'сфера', 'силва', 'руководят', 'рудн', 'работы', 'работу', 'принципе', 'признанные', 'признание', 'приеме', 'права', 'поступать', 'понимаем', 'поверьте', 'перспективу'], ['ягоды', 'является', 'эрекции', 'э', 'щенок', 'шутник', 'ширяк', 'числе', 'чернорабочий', 'цуцык', 'целом', 'функциях', 'фрукты', 'формируются', 'ушел', 'ушами', 'учебники', 'утраченных', 'условиях', 'универсуме'], ['эр', 'штабам', 'хусейна', 'ущерб', 'узлы', 'удерживая', 'удастся', 'удары', 'тридцати', 'сутки', 'стратегически', 'страдают', 'столицу', 'стоит', 'старейшины', 'ста', 'создать', 'скорей', 'сказанные', 'силу'], ['ядра', 'элементов', 'электроники', 'чипы', 'частицами', 'фотосинтеза', 'фото', 'флуоресцентных', 'фиксируется', 'физике', 'упоминает', 'углерод', 'угасают', 'судить', 'судившие', 'странно', 'стороны', 'спинтронике', 'сотен', 'составляющие'], ['экспортные', 'цен', 'сфера', 'страхование', 'стране', 'стабильно', 'средне', 'согласилась', 'словам', 'скорее', 'скажем', 'россия', 'россии', 'протекционизма', 'произойдет', 'прогнозу', 'причем', 'присоединения', 'предшественника', 'поскольку'], ['числе', 'чехии', 'хэви', 'художник', 'франции', 'фильтр', 'фильму', 'фильме', 'фильма', 'фетиш', 'фестивале', 'факт', 'участвует', 'утойя', 'уйдет', 'ужиться', 'удачном', 'удавшаяся', 'тянет', 'транссексуалом'], ['ясли', 'эээ', 'щебетать', 'шутка', 'шутит', 'шок', 'школа', 'швам', 'шапочке', 'читают', 'читала', 'чей', 'цепуре', 'хранит', 'холле', 'фольги', 'фиалки', 'ушел', 'уничтожает', 'унитаз'], ['являясь', 'эстонскую', 'штыки', 'шокирован', 'читано', 'чиновники', 'часов', 'хуже', 'хостел', 'холодца', 'хипстерское', 'фото', 'фанаткой', 'уютно', 'ухабов', 'ухабам', 'утром', 'увидела', 'убылинку', 'убера'], ['экстремизма', 'экстремизм', 'экономическую', 'шариате', 'шаг', 'человечности', 'частности', 'цели', 'уходят', 'устремлениям', 'упрекают', 'точнее', 'террористов', 'террористам', 'терроризму', 'терроризма', 'терроризм', 'террор', 'сша', 'стране'], ['ясно', 'ютюбер', 'экономикой', 'шумихи', 'школьные', 'читал', 'читает', 'чести', 'ценность', 'цензуры', 'храме', 'ходить', 'ходил', 'хайп', 'философами', 'учиться', 'умных', 'улице', 'удивляйтесь', 'увлечении'], ['японии', 'эмиграции', 'честных', 'целом', 'фоне', 'усилия', 'той', 'странах', 'состоящего', 'серьезными', 'связанные', 'свободных', 'свобода', 'ряде', 'рф', 'россия', 'россию', 'россии', 'путина', 'просьбой'], ['частности', 'цинка', 'цветением', 'химикатов', 'х', 'фермы', 'улучшения', 'удивительно', 'требование', 'стока', 'сравнению', 'содержанием', 'снизились', 'связано', 'свинца', 'санкт', 'россия', 'росприроднадзор', 'результате', 'расположения'], ['штаб', 'школьников', 'школа', 'шанхая', 'шанхай', 'числе', 'четверг', 'ченду', 'химии', 'хельсинки', 'форум', 'физике', 'учеников', 'учебный', 'учащимися', 'участия', 'третье', 'технологии', 'тель', 'театры'], ['юмор', 'экспериментальный', 'шансы', ' ...

# %%
evaluate(data['keywords'], rake_keywords)
# Out:
# Precision -  0.02
# Recall -  0.06
# F1 -  0.03
# Jaccard -  0.01

# %% [markdown]
# Попытка дать нормализованные тексты из списков только ухудшила результат.

# %%
def normalize(text):
    
    words = [word.strip(punct) for word in text.lower().split()]
    words = [morph.parse(word)[0] for word in words if word and word not in stops]
    words = [word.normal_form for word in words if word.tag.POS == 'NOUN' or word.tag.POS == 'ADJF' or word.tag.POS == 'ADJS']

    return words

# %%
data['content_norm'] = data['content'].apply(normalize)

# %%
# Попытка 2
r = Rake(language="ru", stopwords=list(stop_words), punctuations=punctuations, min_length=1, max_length=1)

rake_keywords = []
for text in data['content_norm']:
    r.extract_keywords_from_text(' '.join(text))
    keywords = r.get_ranked_phrases()
    #c=r.get_ranked_phrases_with_scores()
    rake_keywords.append(keywords[:20])
print(rake_keywords)
# Out:
# [['момент'], ['скамейка', 'образ', 'манер', 'красота', 'кошка', 'занавеска', 'деньга'], [], ['сезон', 'неудачный', 'кое', 'гран', 'гонка'], ['самый', 'иной', 'есенин', 'выходка'], ['выпускник'], ['свадьба', 'книга', 'задача', 'дыхание'], ['рияда', 'аль'], ['элемент', 'нейробиолог', 'креативный', 'биокомпьютер', 'античный'], ['россиянин'], ['полный', 'интересный', 'довлат', 'автор'], ['сговорчивый', 'русский', 'мальчик', 'злато', 'больница', 'берухо'], ['хипстерский', 'параграф', 'незнающий', 'глаз', 'ганзейский', 'арт'], ['терпимость', 'последствие'], ['телевизор', 'реальный', 'макс', 'канал', 'госдума', 'главный', 'выпуск'], ['обсе', 'британия'], ['осадка', 'зелёный', 'житель'], ['сентябрь', 'последний'], ['финал', 'снятой', 'рука', 'отношение', 'компания', 'город', 'агония'], ['случай'], ['страна', 'премьер', 'нервно', 'би'], ['поза', 'основное', 'влияние'], ['март'], ['учёт', 'ближний'], [], ['попытка', 'половина', 'очередь', 'голосование'], ['риск', 'работа', 'проблема', 'новизна', 'конструкция', 'качество', 'вопрос', 'власть'], ['эмоция', 'проект', 'документ', 'гол', 'байкал'], [], ['страна'], ['тема', 'россия', 'лодка', 'дело'], ['премьер', 'мера', 'изгой'], ['счастливый', 'прошлое', 'карат'], ['склонный', 'опыт', 'момент', 'микроистория', 'звучание', 'восстание'], ['премьер'], ['читатель', 'сей', 'сатирико'], [], ['протяжение', 'мир', 'клуб', 'гольф'], [], ['сми', 'разговор', 'пространство', 'интересный', 'вопрос'], [], ['петербург', 'кома', 'ан'], ['российско', 'август'], ['буэнос'], ['настоящее', 'должность'], ['ценность', 'тишина', 'сто', 'стандарт', 'свой', 'очевидный', 'настроение', 'молодёжь', 'космос', 'контркультура', 'история', 'денежка', 'дело', 'выбор', 'враг', 'взгляд', 'вещь', 'версия', 'бизнесмен', 'америка'], ['страна', 'россия', 'программа', 'народ', 'закон'], [], [], ['экспорта', 'фактор', 'условие', 'рис', 'квота', 'импорт', 'должный', 'вто'], [], [], ['ракетоносец', 'ноябрь', 'модернизация', '95мс'], ['художественно', 'ваала'], ['страна'], ['польско', 'беженец'], ['шахта', 'трамвайщик', 'санкт', 'работа', 'линия'], ['текст', 'решение', 'мусульманин', 'ваххабитам'], ['эк', 'шенберг', 'шаховской', 'шаффгаузен', 'п', 'одер', 'н', 'максим', 'везер', 'балтийско'], ['цель'], ['ликбез'], [], ['наличие', 'деньга', 'внимание'], ['евромайдан', 'ваххаба'], ['язык', 'флорариум', 'турист', 'пластичность', 'ответ', 'образ', 'москвич', 'круглый', 'испытание'], ['проводы', 'политический', 'научно', 'лаборатория'], ['центр', 'прошлое', 'премия'], ['храбрец', 'тэц', 'теплоисточник', 'социально', 'система', 'регион', 'понимание', 'очевидный', 'отрасль', 'котельная', 'квартал', 'источник', 'гкал'], [], ['мнение'], ['предыдущий', 'горожанин'], ['творец', 'супруга', 'святой', 'обитель', 'любовь', 'книга'], ['этаж'], ['сфера', 'последний'], ['нежелательный'], ['тысяча', 'техносфера', 'сторона', 'природа', 'последний', 'показатель', 'образ', 'миллион', 'миллиард', 'климат', 'вид', 'биосфера'], ['рный', 'внутренний', 'вайман'], ['поэзия', 'нежный', 'замечательный'], ['украина', 'рота'], ['рад', 'протяжение'], ['сей', 'свой', 'претензия'], ['участница', 'россия', 'иностранец'], ['католик', 'глубокий'], ['условие', 'страна', 'общество', 'ноябрь', 'конец'], ['столица', 'пространство', 'место', 'горожанин', 'город'], ['язык', 'ютуба', 'фон', 'подросток', 'девочека', 'грузино'], ['округ', 'интерес', 'голос', 'выбор'], ['шайх', 'фахреддин', 'стамбул', 'аль', 'абд'], ['член', 'содер', 'отдых', 'молодая', 'местечко'], [], [], ['тема', 'россия', 'лодка', 'дело'], ['течение', 'победа'], [], ['значимость'], ['картина', 'долгий'], ['нюанс', 'коронеля', 'гонка', 'вираж'], ['танк', 'индекс'], ['рф', 'пробка', 'культура', 'картина', 'должный'], ['свой', 'революция', 'непростой', 'долгий'], [], ['последующий', 'настоящее'], ['существование', 'страна', 'большинство'], ['феномен', 'тенденция', 'монополист', 'инициативность'], ['ребёнок', 'певица', 'н', 'герой', 'анне'], ['январь', 'элита', 'февраль', 'сессия', 'последний', 'политический', 'дол ...

# %%
evaluate(data['keywords'], rake_keywords)
# Out:
# Precision -  0.04
# Recall -  0.02
# F1 -  0.02
# Jaccard -  0.01
